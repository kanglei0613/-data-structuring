# %%
import zipfile
import os

with zipfile.ZipFile('prize.zip', 'r') as zip_ref:
    zip_ref.extractall()

from prize import exlotto, exreciept

print(sorted(exlotto.lotto(48, 6)))
print(exreciept.receipt())
# Out:
# [1, 2, 7, 10, 24, 40]
# 40150797
