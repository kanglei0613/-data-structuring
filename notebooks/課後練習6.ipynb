# %%
ll_students = set(['John', 'Mary', 'Tina', 'Fiona', 'Claire', 'Eva', 'Ben', 'Bill', 'Bert'])
english_pass = set(['John', 'Mary', 'Fiona', 'Claire', 'Ben', 'Bill'])
math_pass = set(['Mary', 'Fiona', 'Claire', 'Eva', 'Ben'])

both_pass = english_pass & math_pass
print("英文與數學都及格", both_pass)

math_fail = all_students - math_pass
print("數學不及格", math_fail)

english_pass_and_math_fail = english_pass - math_pass
print("英文及格且數學不及格", english_pass_and_math_fail)
