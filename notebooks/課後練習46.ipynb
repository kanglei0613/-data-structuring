# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')


X = iris.drop('species', axis=1)
y = iris['species']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

iris_processed = X_scaled_df.copy()
iris_processed['species'] = y_encoded

print(iris_processed.iloc[[71, 87, 75, 140, 124]])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 71       0.310998    -0.592373      0.137547     0.132510        1
# 87       0.553333    -1.743357      0.364896     0.132510        1
# 75       0.916837    -0.131979      0.364896     0.264142        1
# 140      1.038005     0.098217      1.046945     1.580464        2
# 124      1.038005     0.558611      1.103783     1.185567        2
