# %%
midterm1 = int(input("請輸入第一次期中考成績？"))
midterm2 = int(input("請輸入第二次期中考成績？"))
final_exam = int(input("請輸入期末考成績？"))

total_score = midterm1 + midterm2 + final_exam
average_score = total_score / 3

print("總分為", total_score)
print("平均為", average_score)
