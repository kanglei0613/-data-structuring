# %%
def gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a

def lcm(a, b):
    return a * b // gcd(a, b)

a = int(input("請輸入第一個整數："))
b = int(input("請輸入第二個整數："))

print(f"{a}與{b}的最大公因數為 {gcd(a, b)}")
print(f"{a}與{b}的最小公倍數為 {lcm(a, b)}")
# Out:
# 請輸入第一個整數：10
# 請輸入第二個整數：5
# 10與5的最大公因數為 5
# 10與5的最小公倍數為 10
