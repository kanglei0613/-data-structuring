# %%
import itertools

numbers = [4, 6, 7, 8, 11, 24, 35, 37, 40, 48]

combinations = list(itertools.combinations(numbers, 6))

for idx, combo in enumerate(combinations[-5:], start=206):
    print(f"{idx} {combo}")
# Out:
# 206 (8, 11, 24, 35, 40, 48)
# 207 (8, 11, 24, 37, 40, 48)
# 208 (8, 11, 35, 37, 40, 48)
# 209 (8, 24, 35, 37, 40, 48)
# 210 (11, 24, 35, 37, 40, 48)
