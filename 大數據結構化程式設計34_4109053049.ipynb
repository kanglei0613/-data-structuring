# %%
import zipfile
import os

with zipfile.ZipFile('prize.zip', 'r') as zip_ref:
    zip_ref.extractall()

from prize import exlotto, exreciept

lotto_numbers = sorted(exlotto.lotto(48, 6))  # 排序後顯示
print("樂透中獎號碼:", lotto_numbers)

receipt_number = exreciept.receipt()
print("統一發票號碼:", receipt_number)
# Out:
# 樂透中獎號碼: [6, 11, 19, 21, 23, 28]
# 統一發票號碼: 28287777
